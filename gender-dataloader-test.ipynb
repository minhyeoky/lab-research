# %%
import data_loader
import importlib

importlib.reload(data_loader)
# Out:
# <module 'data_loader' from '/home/mhlee/research/data_loader.py'>

# %%
a, b = data_loader.read_list('../data/gender', min_sec=4)
# Out:
# ['../data/gender/train_a/KsponSpeech_041271.pcm.wav', '../data/gender/train_a/KsponSpeech_022800.pcm.wav', '../data/gender/train_a/KsponSpeech_036768.pcm.wav', '../data/gender/train_a/KsponSpeech_009378.pcm.wav', '../data/gender/train_a/KsponSpeech_018049.pcm.wav', '../data/gender/train_a/KsponSpeech_032365.pcm.wav', '../data/gender/train_a/KsponSpeech_015861.pcm.wav', '../data/gender/train_a/KsponSpeech_005752.pcm.wav', '../data/gender/train_a/KsponSpeech_042306.pcm.wav', '../data/gender/train_a/KsponSpeech_011156.pcm.wav', '../data/gender/train_a/KsponSpeech_003170.pcm.wav', '../data/gender/train_a/KsponSpeech_027329.pcm.wav', '../data/gender/train_a/KsponSpeech_040027.pcm.wav', '../data/gender/train_a/KsponSpeech_022063.pcm.wav', '../data/gender/train_a/KsponSpeech_025503.pcm.wav', '../data/gender/train_a/KsponSpeech_013768.pcm.wav', '../data/gender/train_a/KsponSpeech_015186.pcm.wav', '../data/gender/train_a/KsponSpeech_009728.pcm.wav', '../data/gender/train_a/KsponSpeech_042834.
# ...

# %%
len(a), len(b)
# Out:
# (7699, 5642)

# %%
a[:5]
# Out:
# ['../data/gender/train_a/KsponSpeech_041271.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_022800.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_036768.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_009378.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_018049.pcm.wav']

# %%
dl = data_loader.DataLoader(config='./config/cycle-gender-v1-1.json', data_dir='../data/gender')
# Out:
# INFO:root:DataLoader initializing
# ...

# %%
it = iter(dl.generator(data_type='a'))

# %%
next(it)
# Out:
# array([[1.5503669e-01, 2.0009945e-01, 1.6332580e-01, ..., 3.0080470e-01,
#         6.5914631e-02, 1.5723389e-01],
#        [4.3511901e-02, 1.4174420e-01, 1.3654339e-01, ..., 2.3129342e-01,
#         1.7717320e-01, 2.1817401e-01],
#        [6.5976664e-02, 5.3372800e-02, 4.7664512e-02, ..., 3.1843726e-02,
#         2.4749782e-02, 7.4446172e-02],
#        ...,
#        [4.5498140e-04, 7.2869455e-04, 8.0333417e-04, ..., 8.6788861e-03,
#         5.6380508e-03, 2.2128422e-03],
#        [3.4225508e-04, 6.0722395e-04, 1.0273993e-04, ..., 3.9630621e-03,
#         4.0586316e-03, 1.7370664e-03],
#        [6.4962529e-05, 4.4237979e-04, 3.5219619e-04, ..., 2.4412037e-03,
#         2.7162386e-03, 1.3875240e-03]], dtype=float32)

# %%
dl.data_a
# Out:
# ['../data/gender/train_a/KsponSpeech_041271.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_022800.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_036768.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_009378.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_018049.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_032365.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_008188.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_015861.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_005752.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_042306.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_011156.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_003170.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_027329.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_040027.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_041764.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_022063.pcm.wav',
#  '../data/gender/train_a/KsponSpeech_025503.pcm.wav',
# ...
