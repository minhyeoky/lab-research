# %%
# !pip install -r requirements.txt -q

# %%
import json
import tensorflow as tf
import importlib
import seaborn as sns
import numpy as np
import librosa
import pandas as pd
import matplotlib.pyplot as plt
keras = tf.keras

import data_loader
importlib.reload(data_loader)
# Out:
# <module 'data_loader' from '/tf/soundAttGAN/data_loader.py'>

# %%
x, sr = librosa.load('../data/20160109153903_10.wav')

sr, x.shape # = 약 1초
# Out:
# (22050, (20409,))

# %%
dl = data_loader.DataLoader(4)
dl.build()
# y_batch, att_batch = next(iter(dl.next_batch()))

# %%
audio_iter = dl.next_audio()

# %%
xs_shapes = []
for x, r in audio_iter:
    xs_shapes.append(x.shape[0])

# %%
plt.plot(x)

# %%
np.mean(np.array(xs_shapes))
# Out:
# 67252.82233766234

# %%
np.min(np.array(xs_shapes))
# Out:
# 6350

# %%
sns.distplot(xs_shapes)
